# %% [markdown]
# # Fine-tuning a Model for Masked Language Modeling (MLM) Exam

# %% [markdown]
# In this exam, you will be tasked with performing dataset preprocessing and fine-tuning a model for a masked language modeling task. Complete each step carefully according to the instructions provided.
#
# ### Model and Dataset Information
#
# For this task, you will be working with the following:
#
# - **Model Checkpoint**: Use the pre-trained model checkpoint `bert-base-uncased` for both the model and tokenizer.
# - **Dataset**: You will be using the `CUTD/math_df` dataset. Ensure to load and preprocess the dataset correctly for training and evaluation.
#
# **Note:**
# - Any additional steps or methods you include that improve or enhance the results will be rewarded with bonus points if they are justified.
# - The steps outlined here are suggestions. You are free to implement alternative methods or approaches to achieve the task, as long as you explain the reasoning and the process at the bottom of the notebook.
# - You can use either TensorFlow or PyTorch for this task. If you prefer TensorFlow, feel free to use it when working with Hugging Face Transformers.
# - The number of data samples you choose to work with is flexible. However, if you select a very low number of samples and the training time is too short, this could affect the evaluation of your work.

# %% [markdown]
# ## Step 1: Load the Dataset

# %% [markdown]
# Load the dataset and split it into training and test sets. Use 20% of the data for testing.

# %%
# Students Names : Feras Alsayigh, Abdullah Aloufi, Taher Mutanbak, Saud Abusarrah, Abdulah Hafiz

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.0.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.1.4)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.5)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.5)
# Requirement already satisfied: huggingface-hub>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.24.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.11.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.22.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-3.0.0-py3-none-any.whl (474 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.3/474.3 kB 28.8 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.6 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 56.3 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.4 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.2 MB/s eta 0:00:00
# Installing collected packages: xxhash, pyarrow, dill, multiprocess, datasets
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# Successfully installed datasets-3.0.0 dill-0.3.8 multiprocess-0.70.16 pyarrow-17.0.0 xxhash-3.5.0

# %%
import pandas as pd
from transformers import AutoTokenizer
import numpy as np

from datasets import load_dataset

dataset = load_dataset('CUTD/math_df', split="train[:80%]")
dataset = dataset.train_test_split(test_size=0.2)
#Data source
#https://huggingface.co/datasets/CUTD/math_df/tree/main
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# math_df.csv:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/10000 [00:00<?, ? examples/s]

# %%
dataset['train']['text']
# Out:
# ['A human rights lawyer who works alongside the pacifist to uphold justice and fight for peace',
#  'An entertainment lawyer specializing in endorsement and brand deals for athletes',
#  'An entrepreneur and crowdfunding enthusiast who is passionate about the democratization of financial opportunities and an advocate for small businesses.',
#  "A visually impaired student who benefits from the AI system's text-to-speech features",
#  "A graduate student studying film theory and fascinated by the socio-cultural aspects of Mira Nair's movies",
#  "A aspiring political analyst who was inspired by the professor's teaching, but now presents differing viewpoints",
#  'A senior Linux administrator with a focus on system security. She has been working with Linux distributions like RHEL, CentOS, and Ubuntu for over a decade and knows the ins and outs of handling package installations, system configurations, and troubleshooting pc issues.',
#  'A sports reporter assigned to cover the journey and achievements of athletes participating in the Beijing Olympics',
#  "a fashion enthusiast who loves online shopping but hates the hassle of returning items she doesn't like",
#  'A successful entrepreneur who experienced a similar journey and provides guidance on starting a nonprofit organization',
#  'a local tour guide with a deep love for Suzhou history and culture.',
#  "A literature enthusiast who loves discussing and dissecting the themes and symbolism in Bishop's poems",
#  'A retired British actor living in the same apartment building, who often reminisces about their theater experiences in London',
#  'An anti-smuggling officer who continuously trains on the latest techniques for intercepting illegal goods',
#  "A beekeeper who finds inspiration in the retired champion's precision and focus, applying it to their own craft",
#  'an art history professor who pays great attention to historical and sociological context.',
#  'A curious traveler who has always dreamed of experiencing the thrill of diving and uncovering hidden treasures',
#  'A journalist who frequently interviews experts on political forecasting and analysis',
#  'A fellow city council member who disagrees on the allocation of funds for neighborhood safety measures',
#  'A plant-based dietitian who helps retired athletes optimize their nutrition for longevity and overall health',
#  'An independent film distributor focusing on preserving and promoting cultural heritage through cinema',
#  "A fellow music enthusiast who attends every performance of Irving Berlin's music, creating lasting memories together",
#  'A bioengineer who is curious about the intersection of neuroscience and mental health, providing a listening ear and encouragement',
#  "An enthusiastic online shopper who's excited about their new purchase, yet somewhat skeptical and seeking product authenticity confirmation.",
#  'A seasoned entrepreneur who has successfully implemented software solutions for data handling in their own start-up',
#  'A retired nurse with decades of experience in handling public health crises and mentoring younger professionals',
#  'A technology startup developing advanced intrusion detection and prevention systems',
#  'A university student majoring in literature with a strong interest in South Asian women writers and feminist literature.',
#  'A law firm partner looking to streamline their operations and improve efficiency through technology',
#  'A veteran teacher who is passionate about incorporating art and music into the Montessori curriculum',
#  'An older defense attorney with a reputation for ethical and principled representation',
#  'A politically active student majoring in economics who believes in the role of the state in wealth redistribution',
#  "A first-time car buyer who values the car salesperson's ability to simplify complex car features and help them make an informed decision",
#  'a spiritual seeker fascinated by different cultures and drawn to stories of personal journeys, especially those involving family bonds and profound human experiences.',
#  'An education technology startup founder who seeks to incorporate data-driven decision-making in their platform',
#  'A political science professor who specializes in restorative justice model',
#  'A very supportive friend of Michel',
#  "A senior staff member who works closely with the representative, sharing insights on the organization's policies and procedures",
#  'A travel writer and editor who helps secure assignments and publications for the photojournalist',
#  "A literary agent who believes the author's talent lies in capturing the essence of rural life",
#  'A conservative lobbyist who believes that public schools should rely on private funding and competition',
#  'a film critic not easy to impress and is highly critical of cinematic productions.',
#  'A longtime friend and admirer of Demene Hall',
#  'A fan of British YouTubers and lovers of the translated Chinese version of Jack Edwards’ book, "The Uni-Verse: The Ultimate Guide to Surviving University"',
#  'a young Australian music blogger who is an avid fan of Ian Moss.',
#  'A 40-year-old ice hockey enthusiast who enjoys gaming occasionally and stays up-to-date with the latest in sports and technology.',
#  'A 40-year-old woman at average risk of breast cancer who is concerned about her health.',
#  'A history enthusiast and museum curator passionate about the heritage and symbols of monarchy in Canada.',
#  'a retired football player and a former member of Universitario de Deportes',
#  'A seasoned reporter who follows international sailing events and interviews the captain about their achievements and insights',
#  'A young entrepreneur who recently lost their job and is seeking guidance on managing their finances during a difficult time',
#  'A recent computer science graduate trying to improve her skills in Java',
#  "A dedicated tuba player who is the music captain and leader of the school's marching band",
#  'An avid reader of historical fiction set in the antebellum and Civil War era',
#  'a former teammate of Zhu Mi Lei in the Chinese national short track speed skating team',
#  'A parent of a 9-year-old girl who is interested in softball',
#  'A doctoral candidate researching the socio-economic impacts of environmental degradation',
#  'An art conservator who specializes in preserving and repairing artworks with intricate narratives',
#  'A meticulous and ambitious biology major aspiring to become a geneticist',
#  'A group of conservationists and nature enthusiasts who actively participate in environmental initiatives',
#  'A successful advertising executive who provides guidance on identifying collaboration opportunities and building professional networks',
#  'A successful e-commerce startup founder whose business is booming in the same town',
#  'An expert in sustainable governance who advises governments worldwide on integrating sustainability principles into their policies',
#  'A fellow environmental studies student specializing in wetland conservation',
#  "A city council member who recognizes the value of preserving the resident's stories for future generations",
#  'A mid-level software developer seeking to enhance his skills in Java programming',
#  'A retired professor of computer science who offers insights on the theoretical aspects of augmented reality',
#  "A regular internet user who has fallen victim to the persona's cyberattacks and is learning how to protect themselves and recover from the damage",
#  'A medical research scientist conducting studies on emerging infectious diseases',
#  'A football fan who always supports dark-horse teams in Madrid, Spain and has deep knowledge in youth academies in this area.',
#  'A highly skilled Esports player, recognized as one of the best in the industry, who is willing to share their secrets to success',
#  'a young professional interested in the nexus between arts culture, sports, and higher education who came across this bio when researching potential future careers',
#  'A dog trainer who believes that dressing up dogs in costumes can be detrimental to their behavior and well-being',
#  'A geneticist working on cutting-edge research in the field of genetic cloning',
#  'A prospective international student interested in studying business in Europe, with financial constraints and an aspiration for cultural diversity.',
#  'A college athlete who excels in both academics and sports, serving as a role model for balancing gaming and a healthy lifestyle',
#  'A neighborhood mom who likes to share helpful resources in the local online community.',
#  'A science communicator who delves into the scientific accuracy of science fiction movies and TV shows',
#  'An elderly factory worker with personal stories of navigating gender roles during the industrial revolution',
#  'A retired Norwegian senior who starts every day with "God morgen Norge"',
#  'A Ukrainian peace and diplomacy activist.',
#  'A judo sensei who appreciates the similarities and differences between Brazilian Jiu-Jitsu and judo, and seeks collaboration in training methods',
#  'A young local Serbian enthusiast for pop songs and talent shows.',
#  'concerned local citizen from Exeter',
#  'I am a retired theatre actor who has performed in several Shakespearean plays including "Macbeth".',
#  'a computer science professor who teaches data structure and algorithms and likes to inspire thinking by analogy',
#  'a marine biology student who is fascinated by the different forms of sea ice',
#  "A publishing agent who sees the potential in the YouTuber's story and wants to turn it into a book",
#  'A medieval historian with a focus on the lives of English nobility during the Crusades.',
#  'A government financial regulator concerned about the potential risks and systemic impact of algorithmic trading',
#  'A founding member of a wildly successful e-commerce site with expertise in SEO strategy',
#  "A resident of a small Irish village who provides valuable insights and anecdotes about the region's history",
#  'A roommate who binge-watches episodes and engages in hours-long discussions about plot twists',
#  'A veteran player on the same NBA team, known for his leadership and professionalism',
#  'A renowned philanthropist who has dedicated their life to promoting indigenous culture and entrepreneurship',
#  'A respiratory therapist who is on the front lines of treating COPD patients and provides valuable insights',
#  "An author who cherishes quiet spaces and develops plot lines with their partner's expertise in literature",
#  "A respected journalist known for their insightful reviews of the director's productions",
#  'A personal trainer who offers constant encouragement and helps with posing practice',
#  'An older retiree who has a backyard observatory and offers the niece/nephew the opportunity to use their telescope',
#  'A scientist conducting groundbreaking research on clean technologies',
#  "An anthropologist who studies the cultural and social aspects of China's economic development",
#  'A college student studying physics, who often debates cosmological theories and ideas with their parent',
#  'A film critic obsessed with obscure documentaries',
#  'A successful entrepreneur who shares his journey to inspire youngsters to think creatively',
#  'A SQL developer with an easy-going temperament',
#  'An entrepreneur launching a startup and requires a website to establish online presence',
#  'An environmental science professor pushing for universities to divest from fossil fuels',
#  'A sports marketing professional who collaborates with the professor on research projects and industry events',
#  'A seasoned athlete known for their ability to communicate effectively and represent the team well in public',
#  'A student from a similar disadvantaged background who shares the same aspirations in the tech field',
#  'A tax consultant specialized in international tax laws who can help them navigate the complex financial landscape of retiring abroad',
#  'A successful digital marketer with years of experience in driving organic traffic to websites',
#  "An employee of a government agency who discreetly provides access to restricted areas for the persona's investigations",
#  'A former nurse and certified yoga instructor who believes in the positive effects of exercise on overall well-being',
#  'A therapist specializing in trauma who uses Muay Thai as a form of therapy for at-risk youth',
#  "A female student majoring in environmental science with a strong interest in women's empowerment",
#  'A public speaking expert who helps the pilot refine their storytelling skills for impactful presentations',
#  'A renowned business strategist and author who advises the executive on the latest trends in business analytics',
#  "A customer success manager who values clear communication to understand and address clients' needs",
#  'A financial analyst who understands the importance of investing in efficient IT systems',
#  'An interior designer looking to transform a dated kitchen into a modern, functional space',
#  'a movie-enthusiast who loves browsing DVD stores and antiquing',
#  "A renowned science fiction author who challenges the agent's belief by creating thought-provoking and intellectually stimulating stories",
#  'A commercial airline pilot interested in implementing the latest navigation technology',
#  "A teenager who is fascinated by their elder's stories and is inspired to document them in a multimedia project",
#  'An environmental activist who advocates for sustainable and nature-based solutions to mitigate flooding in the city',
#  'A retired army officer who now works in the aerospace industry',
#  'A veterinary researcher studying innovative diagnostic techniques to improve animal health outcomes',
#  'A technology executive from a client organization, concerned about data breaches and cybersecurity risks',
#  'A younger photographer who utilizes drone technology to capture unique perspectives of cultures',
#  'A financial consultant specializing in algorithmic trading strategies',
#  'A person who is not really a fan of online games and considers them somewhat juvenile',
#  'A middle-aged music enthusiast who used to be in a college a cappella group',
#  "A sports and gambling fanatic who enjoys Erik Gibbs's articles",
#  'A concerned parent who relies on consumer safety articles to make informed purchasing decisions',
#  'A content creator in a different niche who collaborates to create visually appealing thumbnails',
#  'A cosmologist specializing in the origin and evolution of life in the universe, engaging in stimulating discussions and debates with the astrobiologist',
#  'A parent who owns a traditional restaurant and has reservations about the unconventional approach',
#  'A renowned law firm specializing in corporate litigation and reputation management',
#  'A former teammate of Nanna Mølbach Johansen in IK Skovbakken, who is very emotional and nostalgic.',
#  'A fellow finance graduate who shares the same career aspirations and is also seeking guidance on tax regulations',
#  'A time traveler from the future who has mastered space-time manipulation and shares their experiences with the young wizard',
#  'A retired nurse who organizes medical conferences and invites the retired surgeon as a keynote speaker',
#  'An aspiring football coach who admires players with unique career paths and is always looking for inspiring stories for his team.',
#  'An ethical hacker who tests mobile security measures and provides valuable insights for improvement',
#  "An influencer who shares the nutritionist's content to raise awareness about food allergies among their followers",
#  'A seasoned cybersecurity consultant who guides and provides insights to the cybersecurity analyst on the latest trends and techniques in malware analysis',
#  'A Marxist economist who offers contrasting viewpoints on the relationship between economics and politics',
#  'An active member of a linguistics forum offering advice and resources for aspiring linguists',
#  'I’m a retired tennis coach who remains a passionate fan of the sport and enjoys tracking the careers of emerging players on the ATP Challenger Tour.',
#  'A tech-savvy entrepreneur developing an AI-based platform to simplify insurance claims',
#  'A part-time bartender who plays defense on the hockey team and enjoys brewing their own beer',
#  'A mother of a child who previously had behavioral problems and successfully overcame them',
#  'a passionate local cultural guide of Canada who loves to show off historical figures.',
#  'A journalist with experience in investigative reporting, always ready to share stories and insights',
#  'A curious teenager who loves exploring the world of open-source software and hacking on Raspberry Pi projects',
#  'a scholar of political science in Kazakhstan, an ardent believer of "People luxury, ruler can be comfortable".',
#  'A software developer for a gaming company who loves creating underwater exploration games based on real-life technology',
#  "A shy and introverted student who has found their voice through the teacher's creative projects and activities",
#  'A movie director known for bringing bestselling novels to life on the big screen',
#  'An innovative and renowned architect who can transform their dream mansion ideas into reality, while also offering insights on potential investment potential and property value enhancement',
#  'A prosecutor who believes that forensic evidence is always reliable and admissible in court',
#  'A pharmaceutical company executive who works closely with the scientist to develop and test new drugs',
#  'An RCMP officer from Ottawa.',
#  'A data scientist who provides insights and trends in the digital marketing field, helping the digital marketing manager stay up-to-date with the latest techniques',
#  'a Japanese resident in Seattle who is a fan of American-style fast food',
#  'an enthusiastic Warsaw resident who is passionate about outdoor activities and local events.',
#  'A professional pet photographer who captures the visual stories needed for compelling magazine articles',
#  'A younger brother who idolizes the persona and constantly tries to convince them to play Super Mario',
#  "A fellow cinephile with a dedicated blog analyzing and discussing Cate Blanchett's performances",
#  "A citizen who fled the rival nation due to the harmful effects of the official's propaganda on their community",
#  "A celebrity personal assistant who values the individual's attention to detail and ability to create a comfortable and enjoyable travel experience",
#  'A retired kindergarten teacher who has dedicated their life to early childhood education advocacy',
#  'A respiratory therapist dedicated to helping people with lung diseases caused by air pollution',
#  'A history professor who provides scholarly insight and historical context for the ancient texts',
#  'A seasoned meteorologist leading a team aiming to understand and predict climate changes',
#  'A sportswriter for a local newspaper in New Mexico',
#  "A professional pianist who appreciates precision and detail in their craft as much as in their sibling's work",
#  'A Japanese entrepreneur who aims to outperform and compete fiercely for trade connections in the same Asian markets',
#  'A renewable energy engineer working on developing more resilient energy solutions',
#  "A grassroots organizer who uses the professor's research findings to challenge systemic issues in local policing practices",
#  'An influencer in the tech industry with a large online following, who can help promote and endorse the drone tech start-up',
#  'A campaign manager who feeds exclusive information to gain an advantage in elections',
#  'A skilled fiddler who strives to preserve the essence of traditional Celtic music in their performances',
#  'A Lebanese tourism promoter',
#  'An obsessed fan of 90s punk rock bands',
#  'A nostalgic motor sports journalist who has been covering the World Rally Championship for decades.',
#  'A doctoral student from a different institution, pursuing research related to the broader field of study and attending the same conferences',
#  'A museum dedicated to showcasing traditional arts and crafts from different cultures',
#  'An active sports blogger who is skeptical about athletes switching sports.',
#  "An electrician parent who has ignited their child's fascination with energy and electricity",
#  'An indigenous leader fighting against illegal logging in their ancestral lands',
#  'A journalist reporting on conflict resolution efforts in the Middle East',
#  'a film critic who dislikes Jason Bateman',
#  'A supply chain analyst with a deep understanding of global market dynamics',
#  'A linguistics researcher who is intrigued by how machine learning algorithms can be utilized in language processing and understanding.',
#  'A history major specializing in indigenous studies who seeks guidance from the tribal elder',
#  'A talented midfielder with an artistic side, expressing their creativity through dribbling and ball control',
#  'A biologist who seeks to apply game theory to ecological systems and animal behavior',
#  'A conservative classic theater aficionado who tends to disagree with the innovative director and prefers traditional plays',
#  "A sibling pursuing a career in music who appreciates the professor's support for exploring different disciplines",
#  "A world-renowned painter who relies on the engineer's platform to showcase and sell their artwork online",
#  'a casual fan of Norwegian music who primarily listens to rock and pop',
#  'A biotech startup founder who suspects unfair competitive practices by a larger rival',
#  'A college student studying engineering who shares fascinating scientific discoveries and experiments with the 5th grader',
#  'A marketing manager responsible for ensuring the packaging and branding align with the overall marketing strategy',
#  'A novelist working on a historical fiction piece set in their own country',
#  'An Azerbaijani historian specializing in the history of local social movements, particularly those related to gender equality, and quite passionate about uncovering neglected historic figures and movements.',
#  'A sports physiotherapist who shares insights on the health benefits and potential risks of different yoga postures',
#  'A freelance illustrator specializing in digital art, collaborating on projects and exchanging creative ideas',
#  "A renowned opera singer who has inspired and influenced Charlotte Church's singing career",
#  'A film producer looking to utilize statistical analysis for predicting box office success and audience preferences',
#  'A mixed media artist who creates surreal and dreamlike artworks',
#  'A talented singer-songwriter who hopes to break into the indie music scene with their unique sound',
#  "a petroleum engineer with a master's degree who is considering a PhD",
#  'A legendary motorcycle stunt artist who provides guidance and inspiration to the entrepreneur',
#  'An elderly woman who shares stories of her youth and imparts wisdom to the nurse',
#  'A successful entrepreneur who also faced a major setback in the past and now guides the executive on the path to redemption',
#  "A software engineer who relies on the blogger's perspectives and analysis to navigate privacy regulations",
#  "A pediatric nurse who assesses the impacts of nutrition on children's growth and development",
#  'A data scientist who values meticulous planning and traditional waterfall development approach',
#  'A high school friend of Jim who has little interest in politics.',
#  'A fellow sci-fi fan who collaborates with them to design and print their own custom figures',
#  'an experienced software engineer who has been through several technical interviews',
#  'A quantitative analyst at an investment bank, applying stochastic calculus to pricing financial derivatives',
#  "A historian specializing in the region's pirate history and legends",
#  'A human rights lawyer who works closely with the journalist to gather evidence and advocate for prison reform',
#  'A former Olympic judoka turned sports historian',
#  'A plant geneticist researching the genetic factors that influence plant resilience to different soil compositions',
#  'An economist studying the potential economic benefits of reallocating defense spending to social programs',
#  "a Yemeni travel blogger living in Sana'a, the capital city of Yemen",
#  "I'm a postmaster general from a similarly sized country with an interest in the global postal landscape.",
#  "A competitive esports organization seeking the coach's expertise to improve team strategies",
#  'A fellow computer science major who shares the same admiration for the software engineer',
#  "A fellow technician with a specialization in a different area, who appreciates the senior technician's willingness to collaborate and exchange expertise",
#  'A college student studying civil engineering with a passion for constructing large-scale train systems',
#  'A city council member who is determined to make the town safer and is open to collaborating with local businesses',
#  'A renowned Indian entrepreneur who has achieved great success in the same industry',
#  'University Professor of Dance',
#  'A working single mother who wants her child to have a strong moral foundation',
#  'a retired sailor who misses the old times of wooden and simple vessels.',
#  "A grouchy senior citizen living in Midwest who doesn't like surprises and abnormalities.",
#  'an eccentric theoretical physicist who often daydreams',
#  'A Taiwanese drama school student aspiring to become an actress',
#  'A database administrator responsible for maintaining and securing a large collection of sports data',
#  'I am a passionate fan and blogger devoted to Spanish football, particularly with a soft spot for underdog teams and deep admiration for the technical and tactical aspects of the game.',
#  'An amateur boxer who balances training with studying sports journalism at college',
#  'a Mexican-American registered nurse',
#  'An electrical engineer with expertise in integrating smart home technology into furniture designs',
#  'a big fan of Mexican music',
#  'An activist running a blog that raises awareness about the importance of peaceful resolutions',
#  'A budding photographer who understands the struggles and triumphs of starting a new venture',
#  'An economist with keen interest and research in the impact of supply chains on global economy',
#  "A renowned art critic who appreciates the scientist's contribution and analyzes the connection between art and science in their reviews",
#  'A sports-loving student-jock who appreciates learning through digital tools',
#  'A veteran Twitch streamer who guides them in creating emotes that resonate with the audience',
#  'A bicycle mechanic who helps cyclists optimize their bike setup for injury prevention and performance enhancement',
#  'A like-minded student who shares their passion for exploring unorthodox philosophical theories',
#  'A sports team owner looking to sell their franchise and seeking a potential buyer',
#  'A small business owner navigating the complexities of legal contracts and regulations',
#  'A graduate student studying publishing and aspiring to become a literary agent themselves',
#  'A graduate student studying visual cognition, often engaged in discussions about the interplay of visual elements and cognition',
#  'A politically savvy representative focused on housing affordability in the city',
#  'A school teacher looking for creative ways to incorporate technology into the curriculum without compromising student well-being',
#  'A journalist with a public health interest, reporting on the ins and outs of emergency medical services',
#  'A junior painter aspiring to master the art of color matching and automobile aesthetics',
#  'a former marching band member who fondly remembers and respects band history',
#  'A magazine editor looking to feature science fiction short stories in their publication',
#  'A philosophy graduate student who shares thought-provoking articles and engages in deep discussions about the intersection of psychology and metaphysics',
#  'A financial analyst seeking assistance in processing and analyzing large amounts of market data',
#  "A focus group of potential customers who can provide feedback on the product's packaging and branding",
#  'A dedicated and curious economics student interested in researching the impact of charity tax policy on social welfare',
#  'A lawyer specializing in aviation law who advises companies on navigating the complex legal landscape surrounding drones',
#  'A local conservation group seeking guidance on incorporating native plants into their restoration projects',
#  'A Japanese art historian and curator at a national museum, collaborating with the government representative to organize cultural events for visiting diplomats',
#  'An athletics historian and consultant',
#  'A hawkish defense analyst who advocates for military solutions over financial peace treaties',
#  'a history and political science professor who has been teaching at a Missouri University for 30 years.',
#  "A stand-up comedian who provides feedback and helps refine the comedian's jokes for online audiences",
#  'A Rugby enthusiast who follows the world series games closely.',
#  "A quick-witted goalkeeper who relies on the defender's strong tackling to keep the opponents at bay",
#  'An official from the Department of Health and Human Services responsible for auditing hospital compliance',
#  'An Austrian political science teacher',
#  'A talented chef who collaborates with the entrepreneur to create unique and mouthwatering bar food',
#  'A home cook who relies on their appliance reviews and recommendations for their own kitchen',
#  'A longtime fan of British music and Rex Orange County',
#  'A Sri Lankan cricket fan who dislikes excuses and appreciates good sportsmanship',
#  'A highly organized and detail-oriented individual who oversees the implementation of eco-friendly policies',
#  'A retired spy mastermind who trained the double agent and now questions their loyalty',
#  '一个泰剧狂热粉丝和资深电视评论人',
#  'a retired woman who prefers quiet, peaceful activities and despises cold weather.',
#  'a Universal theme park fanatic who lives on the East Coast of the U.S.',
#  'A sales manager who measures success based on quotas and revenue generated',
#  'The owner of a conventional textile mill who is resistant to switching to sustainable materials',
#  'A mechanical engineer specializing in powertrain design, working together on optimizing engine performance for the sports cars',
#  'The town librarian who assists the public with genealogical and historical research',
#  "A passionate, middle-aged Toronto Raptors fan who's been waiting for this moment for a long time.",
#  'A chief communications officer who sets strategic messaging goals and oversees media relations',
#  'A customs officer who shares insights on the changing import regulations',
#  'A physician who decided to dedicate their career to providing medical care in war-torn regions',
#  'A social media company looking to improve their recommendation system for personalized content',
#  'A devout Catholic in Rome who looks to the youth pastor for guidance and spiritual support',
#  'A veteran off-road rider',
#  'A mystery novel enthusiast and amateur codebreaker who enjoys discussing puzzles and ciphers',
#  'a millennial dog owner and a conscious consumer living in Fairfield',
#  "An opposing party's campaign manager who is focused on winning at any cost",
#  'A knowledgeable and experienced staff member who provides guidance on puppy care and training',
#  'A resident in Liechtenstein who is bored and weary of the ongoing restrictions due to the pandemic',
#  'A head coach who incorporates data analysis into training strategies to maximize player performance',
#  'A meticulous law firm partner known for their strict document review standards',
#  'A single mother running a non-profit organization that provides healthy meals to underprivileged students',
#  'An elderly woman who relies on the apothecary for her herbal remedies and trusts their expertise',
#  "A retired cricketer and devoted fan of women's cricket.",
#  'A theater actor exploring methods to incorporate martial arts into stage performances',
#  'A professional eSports player specializing in Golf video games.',
#  'A nurse practitioner who carries on the family legacy of providing compassionate care',
#  'A person with a rare disease, excited about the potential of machine learning in finding a cure',
#  'An intern at a rival international law firm seeking competitive intelligence information.',
#  'A newsroom supervisor who encourages the journalist to delve deeper into investigative reporting',
#  'A retired Japanese railway engineer who worked on railway projects for 40 years',
#  "A science fiction fan who constantly challenges the fantasy genre's credibility",
#  'A successful entrepreneur and movie enthusiast who spends their coffee breaks reading amateur scripts',
#  'A charismatic social worker who connects with people and brings them out of their shells',
#  'An older sibling who is a successful radio host and offers guidance and advice on pursuing a career in broadcasting',
#  'A fierce competitor in the Mortal Kombat community who constantly challenges and pushes them to improve their skills',
#  "A dedicated animal shelter manager who oversees the young aspiring veterinarian's volunteer work, providing guidance and opportunities to work with a diverse range of dogs",
#  'A British barrister with a focus on juvenile law.',
#  'A detail-oriented programmer who excels at organizing and managing code repositories',
#  'A packaging material supplier who consults the market research expert to understand the demand for sustainable packaging solutions',
#  'A surrealist painter who is always seeking her next source of inspiration',
#  'A business professor specializing in consumer behavior, who challenges their ideas and theories through online debates',
#  'A nightclub entrepreneur known for their discerning taste in music and trendsetting venues',
#  'A retired language arts teacher with years of experience who provides guidance and advice on curriculum development',
#  'A handbag designer specializing in vegan and sustainable materials',
#  'A celebrated constitutional scholar and author, known for their thought-provoking analyses',
#  'A computer vision researcher with extensive industry experience, guiding and advising on research projects',
#  "A coffee shop owner who shares the story behind their family-owned business and the impact of the travel blogger's spotlight",
#  'An integrative medicine practitioner who specializes in stress reduction techniques like acupuncture and meditation',
#  "A business analyst seeking guidance on leveraging cloud computing for their organization's data analytics",
#  'A sociology major who is researching the effects of poverty on mental health outcomes',
#  'A data analyst who specializes in monitoring and identifying patterns in digital data',
#  'A pediatric surgeon who often debates the pros and cons of technology with in healthcare',
#  'A skeptic and conspiracy theorist who believes that all claims of extraterrestrial life are hoaxes',
#  "A curator who invites the art teacher to display the students' work in a historical art exhibition",
#  'A fellow beginner pixel artist who is also seeking guidance, and together they explore different techniques and learn from each other',
#  "A cinema and literature scholar who sees life's meaning in stories",
#  'A geologist who is currently working at a diamond mine in Botswana',
#  'A visiting lecturer with expertise in classical computing history and its evolution',
#  'A startup founder seeking to build a robust web application using ASP.NET MVC',
#  "A health policy analyst specializing in prisoners' rights",
#  'An elderly woman who shares stories of her adventures as a young artist in Paris',
#  'A fellow lab technician with a knack for troubleshooting and repairing complex lab equipment',
#  'An established food industry executive skeptical about the viability of disruptive startups',
#  "a devoted fan of Prakash Subedi's television shows",
#  'A state health department inspector who assesses healthcare facilities for compliance with HIPAA regulations',
#  "A lawyer specialized in defamation law, providing guidance on how to address the critic's reviews without legal repercussions",
#  'A dedicated yogi who invites them to a local community yoga class and inspires them to explore different styles of yoga',
#  'A skeptical science-fiction fan who enjoys debating about which film genre is more influential',
#  'A journalist in Finland who focused on European Union politics.',
#  "A middle school student who looks up to their older sibling's athletic achievements and aspires to join the cross country team",
#  'A sociologist who studies the impact of society on individual behavior and frequently collaborates with the psychologist on research projects',
#  'A researcher and activist who works to influence legislation and promote reforms in the criminal justice system',
#  'A renowned scholar specializing in comparative studies of fantasy literature across different cultures',
#  'a hardcore fan of reggae music and sound system battles',
#  'A consultant working with educational institutions to implement open-source learning management systems',
#  "I am a film score enthusiast with a deep appreciation for Michael Giacchino's body of work and an encyclopedic knowledge of film music.",
#  "A curious and imaginative child who is fascinated by their friend's beautifully arranged home",
#  "A pharmaceutical company representative who values the professor's insights on patent protection for new drug discoveries",
#  'A devout Roman Catholic and a member of a parish liturgy committee',
#  "A passionate anti-corruption activist who credits the professor's teachings for inspiring their activism",
#  "A journalist and author researching and documenting the impact of Obama's presidency on civil rights",
#  'a dedicated supporter of minor league football teams and an enthusiast for local football history',
#  'A nostalgic old-timer from Brooklyn who once dreamed of living on a houseboat',
#  'A music composition major excited about tracing the evolution of different music genres',
#  'An aging British rock enthusiast and former band member, who spent his youth in the 60s and 70s engulfed in the music scene and now enjoys discovering overlooked international music talents.',
#  'A school resource officer who works closely with the counselor to identify at-risk students and provide intervention and support',
#  "A Singaporean language teacher proud of her country's multilingualism",
#  'I am a recently retired professional ballet dancer who has turned to writing historical fiction based on the lives of renowned ballerinas.',
#  'A college student who is new to the world of graphic novels and seeks guidance from the library assistant',
#  'A cryptographer working in national security, who values the mathematical foundation of his work',
#  'a MySQL performance consultant with over ten years of experience',
#  'A Shakespearian scholar who has been studying Shakespearian plays for years.',
#  "A college student majoring in peace studies, eager to contribute to the non-profit's mission",
#  'An expert in the ethical considerations of using predictive models for genomic analysis',
#  'A renowned chef known for their expertise in creating innovative twists on classic comfort dishes',
#  "An expert in sustainable agriculture who can analyze the rancher's current practices and propose feasible solutions for a smooth transition",
#  "A radio host who features the jazz musician's stories and music on a weekly vinyl-focused show",
#  'A journalism student with a knack for conducting in-depth research on celebrity backgrounds',
#  'A dedicated researcher exploring the integration of artificial intelligence in energy systems',
#  'A gaming journalist who focuses on the technical aspects of video games, such as graphics and gameplay',
#  'A fluent Japanese speaker who regularly participates in language exchange forums and is happy to help beginners',
#  'A physician specializing in medical technology and the intersection of engineering and healthcare',
#  'A geneticist specializing in epigenetic modifications who provides expertise and tools for their research',
#  'A farmer who has used electric fencing to protect livestock for years.',
#  'A feminist film theorist who delves into the intersection of gender, race, and sexuality in film',
#  "An investor interested in the startup's innovative tech product and provides funding and strategic advice to help protect and grow the business",
#  'A documentary filmmaker who captures the stories of local communities impacted by international volunteers',
#  'a 19th century philosopher, who is well-known as a proponent of Newtonian physics.',
#  'a middle-aged millennial who already owns a house',
#  "A retired Puerto Rican geography teacher who loves sharing knowledge about the island's natural beauty.",
#  'A mathematician who argues that theoretical physics must be rooted in experimental evidence',
#  'A former professional basketball player who mentors the child, sharing valuable skills and knowledge',
#  'A senior physician who guides and supports the physician in translating research findings into clinical practice',
#  'A renowned fashion designer who creates custom racing suits and outfits for the race car driver',
#  'A traditionalist fitness coach who advocates for eating whole foods and minimally processed diets without reliance on supplements',
#  "A corporate-sponsored influencer who criticizes the social media influencer's activism as misguided and detrimental to business",
#  'A retired basketball player who played alongside the persona and shares unforgettable memories of their time in the Thunder organization',
#  'A transgender activist seeking to deepen their understanding of transgender issues',
#  'A passionate journalist who loves researching about names and their origins.',
#  'A football fan from Spain who has a great passion for goalkeeping legends and statistics.',
#  'A renowned philosopher who guides her in exploring different philosophical schools of thought and helps her develop a strong ethical foundation',
#  'A neighborhood advocate organizing tree planting projects and promoting green spaces',
#  'A retired statesman known for their diplomatic skills and strategic thinking',
#  "A professional in the music industry who seeks the audiophile's expertise in achieving a warm and authentic sound in recordings",
#  "A web content writer who enjoys the comedian's witty jokes and wants to collaborate on creating engaging website content",
#  "An elderly resident who admires the rebellious student's courage and supports his social causes from afar",
#  'A librarian who prefers watching documentaries over reading books.',
#  'A classmate who excels in design and simulation, offering valuable insights in the field of automotive engineering',
#  'A healthcare technology analyst who provides insights on the latest advancements in cloud security for healthcare providers',
#  'A talented athlete pursuing a degree in sports science, eager to learn from their expertise',
#  'A public policy researcher specializing in equitable resource allocation and community development',
#  "A digital artist who relies on the software engineer's tools to create stunning visual masterpieces",
#  'A politically indifferent student studying computer science in India.',
#  'A retired professor who enjoys sailing as a peaceful and introspective hobby',
#  'a documentary filmmaker passionate about reforming the U.S. criminal justice and mental health systems',
#  "A local bar owner who's always on the lookout for fresh entertainment options for patrons",
#  "A tech-savvy entrepreneur who wants to launch their own app and seeks the freelancer's expertise",
#  'A forum moderator and experienced audio engineer who provides valuable feedback on their projects',
#  'An ambitious undergraduate deliberating on choosing medieval culture as the focus for their history major',
#  'an experienced role-playing games (RPGs) community moderator',
#  'A renowned peace activist and Nobel laureate who has dedicated their life to fighting for equality and justice',
#  "An official from a regulatory agency responsible for drafting and implementing AI regulations, seeking the lawyer's input and working together to strike a balance",
#  'A senior technical artist who has extensive knowledge and experience in creating game assets',
#  'A middle-aged Kurdish woman originally from Çaybaşı who has been living abroad for several years.',
#  'A professional baseball player who used to play little league with the optometrist',
#  'A remote software engineer who recently bought a new home and can provide advice on online real estate transactions',
#  'A retired company executive with years of experience dealing with transition periods',
#  'A playwright and theater director who passionately defends the power and intimacy of live performances',
#  'An experienced and highly regarded composer who has paved the way for a new generation of film composers',
#  'An animated character designer who adores vibrant colors and quirky features.',
#  'A former captain of the Essendon Football Club who shares a deep bond of friendship and camaraderie with the retired player',
#  'A young Swedish art student and lover of folklore',
#  'A renowned photographer who has been capturing significant historical events for decades',
#  'A fellow history enthusiast who specializes in researching and documenting the financial success and failures of businesses over time',
#  'A co-worker who shares the same concerns and collaborates with the worried spouse to ensure safety measures are in place',
#  'A linguistics professor who collaborates with the interpreter to develop language resources for journalists',
#  'A fellow language enthusiast who shares the same passion for interpretation and can practice and study together',
#  'A diplomat who frequently throws luxurious parties and appreciates unique gastronomic experiences',
#  'An orthopedic surgeon who recognizes the importance of mental health in the rehabilitation process and seeks collaboration with the sports psychologist',
#  "A community leader passionate about promoting local tourism and supporting the campsite's initiatives",
#  'A professional basketball player who exclusively uses their high-quality jerseys and equipment in games',
#  'A nurse practitioner specializing in pediatric emergency care, always updated with the latest treatment procedures',
#  'A parent who operates a marine wildlife rescue center and shares stories of successful rehabilitation and release',
#  'A curious undergraduate majoring in sociology, eager to explore the complexities of conflict',
#  'A reliable and efficient moving company that specializes in helping homeowners transition to a new place smoothly',
#  'A real estate broker who gives practical advice on risk diversification',
#  "A rebellious undergraduate challenging the professor's perspectives and advocating for progressive change",
#  'A behavioral psychologist who conducts research on motivation and behavior change',
#  'A frontend developer who relies on the well-structured databases created by the software engineer to display data in user-friendly interfaces',
#  'A marketing executive for a non-profit organization, balancing work with a passion for social causes',
#  'A busy corporate lawyer always in need of better strategies to manage their workload',
#  'An aging former Scottish track athlete who competed against Jamie Henderson',
#  'A die-hard Houston Astros fan since childhood.',
#  'A para-athlete trainer who understands the unique needs and challenges of para-athletes',
#  'A fellow journalism graduate who is starting their own online publication and offers collaboration opportunities',
#  'a German citizen who jogged in the park with Galić during the daytime, not knowing his true identity.',
#  'a novel lover who enjoys reading about authors and their works.',
#  'A young aspiring pilot interested in the future of aviation technology and its impact on their career',
#  "A social worker who utilizes the statistician's findings to advocate for marginalized communities",
# ...
#  'An executive from a major sports league who is looking for legal counsel to navigate complex business transactions',
#  'a hipster who prefers vintage stuff and handcrafted indie items',
#  'An event manager who plans tech conferences featuring discussions on the future of transportation',
#  'A descendant of Mary Osburn Adkinson',
#  'A mechanical engineer who collaborates with the operator to implement innovative automation solutions',
#  'a conservative American who believes in personal responsibility and minimal government intervention.',
#  'A wise and experienced priest who shares intriguing stories from the early days of the Catholic Church',
#  'An economics professor who uses game theory to make strategic choices in fantasy leagues',
#  'A sharp-witted lawyer who strategizes the best approach to protect the whistleblower and prosecute the guilty parties',
#  'A scientist conducting studies on the long-term effects of certain supplements',
#  'A retired concert promoter who organized several memorable concerts for the band in their prime',
#  "A teacher who appreciates the programmer's feedback on lesson plans and instructional materials",
#  "A politically engaged senior citizen who volunteered during McGovern's 1972 presidential campaign",
#  "An external auditor who assesses the compliance and efficiency of the forensic lab's operations",
#  'A historian specializing in local transportation who is writing a book on the history of the Aberdeen tramway system',
#  "A campaign manager who uses the climate scientist's research to develop effective messaging and policy platforms for the senator's campaign",
#  'A strength and conditioning coach who understands the demands of high-level sports and can offer advice on nutrition',
#  'A financial advisor who is optimistic about the high yield bond market',
#  "A meticulous expert who provides accurate valuations for the art collector's acquisitions",
#  'A climate scientist championing the adoption of carbon capture to mitigate climate change',
#  "A data journalist who seeks the R programmer's expertise in extracting and analyzing data for investigative reporting",
#  'A widowed author slowly finding healing through writing a memoir of their late spouse',
#  'An experienced clinical trial coordinator who supports and guides young oncologists in their research endeavors',
#  'A logistics officer in the NGO, responsible for ensuring necessary medical supplies reach in time',
#  'A medical doctor in a peaceful town who constantly worries about their adventurous sibling',
#  'A professor of religious studies from a different faith tradition, who values open conversations and mutual respect',
#  'A competitive student fascinated by history, always eager to learn about past civilizations and empires',
#  'A fellow competitor who emphasizes the importance of performance over aesthetics, leading to friendly competition and constant drive to outdo each other',
#  'A marketing specialist who helps promote the scooter service app and increase its user base',
#  "A venture capitalist with a keen interest in emerging technologies, investing in the researcher's 5G projects",
#  'A retired police officer who enjoys analyzing the ethical implications of violent scenes in novels',
#  'A basketball coach from a small town, interested in learning more about the strategies employed by professional teams',
#  'A retired coach with years of experience and a strong emphasis on integrity',
#  'A fellow retiree who has successfully built multiple streams of passive income and is willing to share their strategies',
#  'A war veteran with complex physical and psychological trauma, relying on the nurse for specialized care and support',
#  'A detail-oriented publication editor who values raw and unfiltered narratives',
#  'a Polish music student studying at the Academy of Music in Łódź',
#  'A bioethics major seeking guidance on navigating the ethical complexities of scientific research',
#  'A mechanical engineer with experience in building complex systems, eager to help their child fulfill their scientific ambitions',
#  'An artistic genius who meticulously recreates historical settings with attention to detail',
#  'A tech startup CEO with a knack for accidentally courting controversy online',
#  "A tabletop gamer who appreciates the novelist's ability to bring fantasy worlds to life through storytelling",
#  'A vigilant expert in detecting and mitigating cyber threats, determined to stop the hacker and the industrial spy',
#  'A reclusive genius hacker who admires the skills and audacity of the protagonist',
#  'a freelance makeup artist who is a big fan of Silvina Knight.',
#  'A television series director who believes deeply in the power of visual art to evoke emotion',
#  'A medical doctor working in a community clinic that collaborates with the social worker to provide comprehensive care',
#  'A university athletic director always on the lookout for inspiring sports stories and alumni engagement opportunities',
#  'A junior Java programmer striving to improve his knowledge on interfaces and exceptions.',
#  'A classmate who is more inclined towards sports and outdoor activities and often joins in for digital learning sessions',
#  "A retired actor who volunteers as an usher and helps promote the theater's events",
#  'An ambitious International Relations major focusing on Russian studies and interested in understanding the disparity in narratives',
#  'A veteran stage actor who has become a trusted friend and confidant',
#  'An adventurous retiree from Australia who writes detailed letters about their hiking trips through the Outback',
#  'An aspiring indie game developer who uses Unity and C# to create innovative game mechanics',
#  'A representative from a software company offering a customer relationship management (CRM) platform specifically designed for small businesses',
#  'An aspiring Japanese actress',
#  'An adventurous school teacher who brings her students to the library for monthly book clubs',
#  'A Mercedes-Benz enthusiast living just down the street, often seeking advice on car modifications',
#  'A music agent who scouts for talented artists and helps them secure record deals',
#  'a rugby fan who is excited about this upcoming World Rugby SVNS season',
#  'A primary school teacher who incorporates moral teachings into her curriculum',
#  'An active member of an online software development forum known for their expertise in system design and optimization',
#  'A young student studying literature and aspiring to be a writer',
#  "A property appraiser who provides unbiased assessments of the real estate mogul's investments",
#  'a biology Ph.D. specializing in taxonomy research in sub-Saharan Africa.',
#  'An accomplished data scientist with years of experience in various analytics domains',
#  'An event coordinator responsible for inviting and coordinating speakers for React.js conferences',
#  'A practical and somewhat skeptical local teacher who drops in for the discussions to offer a different perspective',
#  "A group of aspiring writers who are inspired by the writer's creativity and eagerly await their next piece to discuss and analyze",
#  'A prominent politician from another country who shares a mutual interest in international security',
#  'A renowned scholar in early modern literature, specifically Shakespearean sonnets',
#  'A research assistant conducting a study on the effects of social media on political engagement',
#  'A technology integration specialist who collaborates on incorporating interactive online resources into the newsletter',
#  "A culinary expert leading food and wine tasting tours in Melbourne's vibrant restaurant scene",
#  'A talented photographer who started out as a loyal follower and has now become the official photographer for the influencer',
#  'A local business owner invested in favorable ordinances to support small businesses',
#  'A music composition student who is eager to incorporate Indian classical elements into their own compositions',
#  "A children's book author who creates stories that promote mindfulness and meditation for young readers",
#  'An influential game designer who is well-connected and can provide valuable career opportunities',
#  'A systems biology professor constructing models to understand complex biological systems',
#  'A fellow data scientist who shares unique approaches to solving complex problems',
#  'A retired professional athlete, now working as a tough but respected local coach',
#  "An aspiring musician who finds inspiration in the guitarist's raw talent and dedication to their craft",
#  'A retired screenwriter, recognized for their critically acclaimed work, who now teaches at a film school',
#  'A dedicated social worker, also a twin sibling, passionate about mental health advocacy',
#  'A historian who focuses on gender and sexuality in medieval Europe, offering alternative perspectives and narratives',
#  'a law professor and head of the law department at a reputed university',
#  'A lifestyle coach who provides advice on maintaining productivity and discipline in one’s personal and professional life',
#  'A finance officer at a non-governmental organization who is interested in implementing digital financial platforms',
#  'A cultural anthropologist conducting fieldwork on indigenous media practices',
#  'A logistics coordinator with exceptional organizational skills to manage shipping schedules and paperwork',
#  'An innovative designer passionate about creating a user-friendly and visually appealing online platform',
#  'An experienced software engineer with expertise in natural language processing and machine learning, who is excited about integrating AI into customer service',
#  'a retired Olympic athlete who was once a competitor in the same luge events as Felix Loch',
#  'A retired philosopher who previously studied the compatibility of science and faith',
#  'A dietitian with a knack for creating healthy recipes and a love for puns',
#  "A student activist who amplifies the professor's analyses on social media platforms",
#  'A curator of a war museum who is interested in displaying the artifacts recovered from the aircraft wrecks',
#  'An elderly homeowner who is considering a kitchen renovation',
#  'A non-Muslim history enthusiast who appreciates the importance of understanding different cultures',
#  'A board member who advocates for diversity and inclusion in the workplace',
#  'A literary agent also keen on securing film and TV deals for their clients, creating a friendly yet competitive environment',
#  'A podcast host who invites the historian to discuss the intersection of digital humanities and historical research on a popular history show',
#  'A local food expert from Eastern Europe who guides them through hidden culinary gems',
#  "A graduate student conducting research on the impact of World War I on women's suffrage",
#  'A marine research institute director overseeing various research projects',
#  'A data analytics intern eager to learn advanced techniques for data manipulation and visualization',
#  'A fellow PhD candidate researching innovative approaches to peacebuilding in post-conflict societies',
#  'A progressive art educator with a passion for different art styles and innovative teaching methods',
#  'A dedicated enthusiast who meticulously recreates naval uniforms and equipment for living history demonstrations',
#  'A marketing executive from a rival social media platform who believes in aggressive competition and seeks to outshine the privacy-focused platform',
#  'An independent filmmaker who often debates artistic integrity vs. commercial success with their critic friend',
#  'Um professor universitário de psicologia que está realizando um estudo sobre o impacto das redes sociais na saúde mental e precisa de orientação sobre as preocupações legais relacionadas à privacidade dos participantes',
#  'a retired Japanese anime and Tokusatsu enthusiast reflecting on the career of a voice actor',
#  'A community organizer who works closely with the police officer and firefighter to plan and execute various outreach events',
#  'A seasoned cyclist with strategic race tactics and experience in stage races',
#  'A younger brother with a natural talent for playing drums and dreams of touring with a famous rock band',
#  'A globe-trotting archaeologist who assists in locating and authenticating ancient artifacts',
#  'A currency expert who navigates the volatile forex market and provides insights into managing currency risks for international investments',
#  'A skeptical rationalist who constantly questions the basis of their philosophical arguments',
#  "A concerned parent who worries about the blogger's future and financial stability",
#  'A fellow musician who has also lost motor function and is exploring alternative ways of expressing their creativity',
#  'A literature major captivated by the narrative techniques in historical fiction novels',
#  "A private investigator who shares a similar background and uses the informant's connections to gather information",
#  'A cashier who interacts with customers daily, witnessing the impact of affordable and nutritious food on their lives',
#  'A risk-averse finance director requiring thorough cost-benefit analyses for all project expenditures',
#  'A rival business owner who seeks to outsmart and outperform the business owner in risk management',
#  "A reporter who admires the organizer's efforts and writes articles to raise awareness about the need for reform",
#  'A homeowner who has a limited budget on electrical repairs',
#  'A fellow foreign student at Florida State University majoring in International Relations',
#  "A childhood friend and mechanic who constantly fine-tunes the racer's car to give them the best chance of victory",
#  'A curator of natural history museums, sharing insights and knowledge about fossils, minerals, and scientific exhibits',
#  'A fellow researcher passionate about promoting ethical behavior in organizations, connecting through an online research forum',
#  "An artist who specializes in murals and is commissioned to paint a travel-themed mural on the bakery's exterior",
#  'A data scientist who specializes in machine learning and shares insights on the importance of data structuring in coding',
#  "A young, passionate elementary school teacher who's actively searching for new job opportunities.",
#  'A disillusioned teacher who is willing to provide insider information on corrupt practices within schools',
#  'A teenager who regularly visits the senior citizen and records their stories to preserve them for future generations',
#  'A freelance graphic designer who is meticulous about the condition of their rented space',
#  'A trained professional who provides information and guidance on the risks and options associated with genetic conditions',
#  'A data scientist specializing in blockchain analytics and optimizing decentralized protocols',
#  'A social entrepreneur who collaborates with the tribal leader to create sustainable economic opportunities for the community',
#  'A manufacturing company seeking assistance in managing and mitigating groundwater contamination',
#  'A local politician with a passion for social causes and a strong network of supporters',
#  "A granddaughter who shares the retired librarian's love for literature and often discusses their favorite romance novels together",
#  "A music historian who appreciates the DJ's ability to modernize classic songs for younger audiences",
#  'a financially prudent and decisive homemaker',
#  "A talented ballet dancer who appreciates their grandmother's unwavering support",
#  'A geography professor who educates and empowers students about climate change and its effects on marginalized communities in the Global South',
#  'an aspiring filmmaker and fan of James Hughes',
#  'An activist who advocates for equitable education opportunities and supports the research study',
#  "A reader deeply impacted by the transcendentalist ideas present in the author's works",
#  'A fellow professor who had been secretly hoping to get promoted to the Dean of Arts',
#  ...]

# %%
dataset['train'].column_names
# Out:
# ['Unnamed: 0', 'text']

# %% [markdown]
# ## Step 2: Load the Pretrained Model and Tokenizer

# %% [markdown]
# Use a pre-trained model and tokenizer for this task. Initialize both in this step.

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForMaskedLM
# I chose this tokenizer based on hugging face doc since I think it suitable for masked problem
#https://huggingface.co/docs/transformers/tasks/masked_language_modeling

tokenizer = AutoTokenizer.from_pretrained("distilbert/distilroberta-base")
model = AutoModelForMaskedLM.from_pretrained("distilbert/distilroberta-base")
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/331M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilbert/distilroberta-base were not used when initializing RobertaForMaskedLM: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# ## Step 3: Preprocess the Dataset

# %% [markdown]
# Define a preprocessing function that tokenizes the text data and prepares the inputs for the model. Ensure that you truncate the sequences to a maximum length of 512 tokens and pad them appropriately.
#
# **Bonus**: If you performed more comprehensive preprocessing, such as removing links, converting text to lowercase, or applying additional preprocessing techniques.

# %%
def preprocess_function(examples):
    return tokenizer([" ".join(x) for x in examples["text"]])

# %%
tokenized_ds = dataset.map(
    preprocess_function,
    batched=True,
    num_proc=4,
    remove_columns=dataset["train"].column_names,
)
# Out:
# Map (num_proc=4):   0%|          | 0/6400 [00:00<?, ? examples/s]
# Map (num_proc=4):   0%|          | 0/1600 [00:00<?, ? examples/s]

# %%
tokenized_ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask'],
#         num_rows: 6400
#     })
#     test: Dataset({
#         features: ['input_ids', 'attention_mask'],
#         num_rows: 1600
#     })
# })

# %%
block_size = 512

# From the doc to concatenate and group
#https://huggingface.co/docs/transformers/tasks/masked_language_modeling
def group_texts(examples):
    # Concatenate all texts.
    concatenated_examples = {k: sum(examples[k], []) for k in examples.keys()}
    total_length = len(concatenated_examples[list(examples.keys())[0]])
    # We drop the small remainder, we could add padding if the model supported it instead of this drop, you can
    # customize this part to your needs.
    if total_length >= block_size:
        total_length = (total_length // block_size) * block_size
    # Split by chunks of block_size.
    result = {
        k: [t[i : i + block_size] for i in range(0, total_length, block_size)]
        for k, t in concatenated_examples.items()
    }
    return result

lm_dataset= tokenized_ds.map(group_texts, batched=True, num_proc=4)
# lm_dataset_test = tokenized_ds.map(group_texts, batched=True, num_proc=4)
# Out:
# Map (num_proc=4):   0%|          | 0/6400 [00:00<?, ? examples/s]
# Map (num_proc=4):   0%|          | 0/1600 [00:00<?, ? examples/s]

# %% [markdown]
# ## Step 4: Define Training Arguments

# %% [markdown]
# Set up the training configuration, including parameters like learning rate, batch size, number of epochs, and weight decay.

# %%
from transformers import TrainingArguments
training_args = TrainingArguments(
    output_dir="my_awesom_model",
    eval_strategy="epoch",
    learning_rate=2e-5,
    num_train_epochs=3,
    weight_decay=0.01,
)

# %% [markdown]
# ## Step 5: Initialize the Trainer

# %% [markdown]
# Initialize the Trainer using the model, training arguments, and datasets (both training and evaluation).

# %%
from transformers import DataCollatorForLanguageModeling

tokenizer.pad_token = tokenizer.eos_token
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm_probability=0.15)

# %%
from transformers import Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=lm_dataset["train"],
    data_collator=data_collator,
    eval_dataset = lm_dataset["test"]
)

# %% [markdown]
# ## Step 6: Fine-tune the Model

# %% [markdown]
# Run the training process using the initialized Trainer to fine-tune the model on the masked language modeling task.

# %%
lm_dataset['train']
# Out:
# Dataset({
#     features: ['input_ids', 'attention_mask'],
#     num_rows: 1408
# })

# %%
lm_dataset['test']
# Out:
# Dataset({
#     features: ['input_ids', 'attention_mask'],
#     num_rows: 348
# })

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='528' max='528' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [528/528 01:42, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.225745</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>1.108353</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.348100</td>
#       <td>1.066714</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=528, training_loss=1.3379427880951853, metrics={'train_runtime': 104.1387, 'train_samples_per_second': 40.561, 'train_steps_per_second': 5.07, 'total_flos': 560194511044608.0, 'train_loss': 1.3379427880951853, 'epoch': 3.0})

# %% [markdown]
# ## Step 7: Inference

# %% [markdown]
# Use the fine-tuned model for inference. Create a pipeline for masked language modeling and test it with a sample sentence.

# %%
dataset['test']['text'][0:3]
# Out:
# ["A granddaughter inspired by the nurse's compassion, who aspires to follow in their footsteps and become a geriatric nurse",
#  'An aerospace engineer researching biomimicry and aerodynamics',
#  'A data scientist who applies mathematical models to analyze patterns in abstract art']

# %%
# I'll chose the third one and mask the word bookshop

# %%
text = "A data scientist who applies mathematical models to analyze <mask> in abstract art"

# %%
from transformers import pipeline

mask_filler = pipeline("fill-mask", model=model, tokenizer= tokenizer )
mask_filler(text, top_k=3)
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# [{'score': 0.07663597166538239,
#   'token': 8117,
#   'token_str': ' patterns',
#   'sequence': 'A data scientist who applies mathematical models to analyze patterns in abstract art'},
#  {'score': 0.03671473264694214,
#   'token': 9126,
#   'token_str': ' errors',
#   'sequence': 'A data scientist who applies mathematical models to analyze errors in abstract art'},
#  {'score': 0.030674902722239494,
#   'token': 5550,
#   'token_str': ' differences',
#   'sequence': 'A data scientist who applies mathematical models to analyze differences in abstract art'}]
